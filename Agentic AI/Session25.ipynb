# %%
'Assistant.py is connected with this file'

# %%
print(detect_intent("Show me my upcoming movie bookings"))
print(detect_intent("Play some music"))
print(detect_intent("What is the weather today?"))

# %%
print(select_tool("show_bookings"))
print(select_tool("play_music"))
print(select_tool("get_weather"))

# %%
st.session_state.conversation_history
history = st.session_state.conversation_history[-3:]

# %%
with st.spinner("Gathering information..."):
    time.sleep(1)

with st.spinner(f"Executing {tool}..."):
    time.sleep(1)
