# %%
# Task 1

import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# Load Dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

# Model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    epochs=5,
    validation_split=0.2
)

val_acc = history.history['val_accuracy'][-1]

print("Validation Accuracy:", val_acc)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 15s 1us/step
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\shard\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9216 - loss: 0.2697 - val_accuracy: 0.9639 - val_loss: 0.1284
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9660 - loss: 0.1125 - val_accuracy: 0.9656 - val_loss: 0.1122
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9762 - loss: 0.0787 - val_accuracy: 0.9703 - val_loss: 0.1008
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9818 - loss: 0.0579 - val_accuracy: 0.9707 - val_loss: 0.0951
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9856 - loss: 0.0449 - val_accuracy: 0.9724 - val_loss: 0.0948
# Validation Accuracy: 0.9724166393280029

# %%
# Task 2

from tensorflow.keras import regularizers

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0

model = Sequential([
    Flatten(input_shape=(28, 28)),

    Dense(
        128,
        activation='relu',
        kernel_regularizer=regularizers.l2(0.01)
    ),

    Dense(
        64,
        activation='relu',
        kernel_regularizer=regularizers.l2(0.01)
    ),

    Dense(
        10,
        activation='softmax',
        kernel_regularizer=regularizers.l2(0.01)
    )
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    epochs=5,
    validation_split=0.2
)

val_acc = history.history['val_accuracy'][-1]

print("Validation Accuracy:", val_acc)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8843 - loss: 1.0807 - val_accuracy: 0.9091 - val_loss: 0.8062
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9027 - loss: 0.8193 - val_accuracy: 0.9132 - val_loss: 0.7849
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9050 - loss: 0.8016 - val_accuracy: 0.9101 - val_loss: 0.7831
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9064 - loss: 0.7943 - val_accuracy: 0.9178 - val_loss: 0.7610
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9078 - loss: 0.7892 - val_accuracy: 0.9134 - val_loss: 0.7725
# Validation Accuracy: 0.9134166836738586

# %%
# Task 3

from tensorflow.keras.layers import Dropout

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0

model = Sequential([
    Flatten(input_shape=(28,28)),

    Dense(128, activation='relu'),
    Dropout(0.5),

    Dense(64, activation='relu'),
    Dropout(0.5),

    Dense(10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    epochs=5,
    validation_split=0.2
)

val_acc = history.history['val_accuracy'][-1]

print("Validation Accuracy:", val_acc)
# Out:
# c:\Users\shard\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8011 - loss: 0.6439 - val_accuracy: 0.9398 - val_loss: 0.2050
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9032 - loss: 0.3451 - val_accuracy: 0.9566 - val_loss: 0.1610
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9199 - loss: 0.2866 - val_accuracy: 0.9605 - val_loss: 0.1376
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9287 - loss: 0.2546 - val_accuracy: 0.9647 - val_loss: 0.1248
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9333 - loss: 0.2394 - val_accuracy: 0.9650 - val_loss: 0.1222
# Validation Accuracy: 0.9649999737739563

# %%
# Task 4

from tensorflow.keras.layers import (
    Dense,
    Flatten,
    BatchNormalization,
    Activation
)

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0

model = Sequential([

    Flatten(input_shape=(28,28)),

    Dense(128),
    BatchNormalization(),
    Activation('relu'),

    Dense(64),
    BatchNormalization(),
    Activation('relu'),

    Dense(10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    epochs=5,
    validation_split=0.2
)

print("Training Accuracy:")
print(history.history['accuracy'])

print("\nValidation Accuracy:")
print(history.history['val_accuracy'])
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9203 - loss: 0.2798 - val_accuracy: 0.9656 - val_loss: 0.1207
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9622 - loss: 0.1242 - val_accuracy: 0.9709 - val_loss: 0.0903
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9710 - loss: 0.0923 - val_accuracy: 0.9740 - val_loss: 0.0869
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9769 - loss: 0.0733 - val_accuracy: 0.9759 - val_loss: 0.0868
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9799 - loss: 0.0620 - val_accuracy: 0.9749 - val_loss: 0.0862
# Training Accuracy:
# [0.9202708601951599, 0.9622083306312561, 0.9710416793823242, 0.976895809173584, 0.979895830154419]
#
# Validation Accuracy:
# [0.965583324432373, 0.9709166884422302, 0.9739999771118164, 0.9759166836738586, 0.9749166369438171]

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train')

plt.plot(history.history['val_accuracy'], label='Validation')

plt.title('Batch Normalization Performance')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.legend()
plt.show()

# %%
# Task 5

import tensorflow as tf

from tensorflow.keras.callbacks import EarlyStopping

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0

model = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=2,
    restore_best_weights=True
)

history = model.fit(
    X_train,
    y_train,
    epochs=20,
    validation_split=0.2,
    callbacks=[early_stop]
)

print("Actual Epochs Run:")
print(len(history.history['loss']))

print("\nFinal Validation Accuracy:")
print(history.history['val_accuracy'][-1])
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9234 - loss: 0.2656 - val_accuracy: 0.9603 - val_loss: 0.1364
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9664 - loss: 0.1131 - val_accuracy: 0.9647 - val_loss: 0.1177
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9768 - loss: 0.0770 - val_accuracy: 0.9708 - val_loss: 0.1001
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9811 - loss: 0.0596 - val_accuracy: 0.9718 - val_loss: 0.0952
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9858 - loss: 0.0452 - val_accuracy: 0.9719 - val_loss: 0.0997
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9885 - loss: 0.0369 - val_accuracy: 0.9747 - val_loss: 0.0885
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9904 - loss: 0.0304 - val_accuracy: 0.9728 - val_loss: 0.1028
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9912 - loss: 0.0254 - val_accuracy: 0.9749 - val_loss: 0.0988
# Actual Epochs Run:
# 8
#
# Final Validation Accuracy:
# 0.9749166369438171
