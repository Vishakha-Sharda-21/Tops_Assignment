# %%
import numpy as np 
X = np.array([ [80,4], [75,3], [15,0], [20,1], [90,5], [10,0] ]) 
y = np.array([1,1,0,0,1,0])

# %%
weights = np.zeros(2) 
bias = 0 
learning_rate = 0.01

# %%
def step(x): 
    return 1 if x >= 0 else 0

for epoch in range(100): 
    for i in range(len(X)): 
        linear = np.dot(X[i], weights) + bias 
        prediction = step(linear) 
        error = y[i] - prediction 
        weights += learning_rate * error * X[i] 
        bias += learning_rate * error 
        
print("Weights:", weights)
print("Bias:", bias)
# Out:
# Weights: [0.2  1.51]
# Bias: -2.489999999999991

# %%
for sample in X: 
    pred = step(np.dot(sample, weights) + bias) 
    print(sample, "Prediction:", pred)
# Out:
# [80  4] Prediction: 1
# [75  3] Prediction: 1
# [15  0] Prediction: 1
# [20  1] Prediction: 1
# [90  5] Prediction: 1
# [10  0] Prediction: 0
