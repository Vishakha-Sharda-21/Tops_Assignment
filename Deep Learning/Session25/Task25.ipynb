# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Sample daily step counts
steps = np.array([4000, 4200, 4300, 4100, 4500, 4700, 4800, 5000])

# Create input-output sequences
X = []
y = []

for i in range(len(steps)-3):
    X.append(steps[i:i+3])
    y.append(steps[i+3])

X = np.array(X)
y = np.array(y)

# Reshape for LSTM
X = X.reshape((X.shape[0], X.shape[1], 1))

# Build LSTM Model
model = Sequential([
    LSTM(32, input_shape=(3,1)),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

# Train Model
model.fit(X, y, epochs=50, verbose=0)

# Predict Next Value
prediction = model.predict(X[-1].reshape(1,3,1))

print("Predicted Next Step Count:", prediction[0][0])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\shard\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Predicted Next Step Count: 0.1811515

# %%
import tensorflow as tf
import numpy as np

# Binary sequence
X = np.random.randint(0, 2, (20, 10, 1)).astype(np.float32)
y = np.random.randint(0, 2, (20, 1)).astype(np.float32)

# Basic RNN Model
model = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(8, input_shape=(10,1)),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.BinaryCrossentropy()

# Training Loop
for epoch in range(5):

    with tf.GradientTape() as tape:

        predictions = model(X)

        loss = loss_fn(y, predictions)

    gradients = tape.gradient(loss, model.trainable_variables)

    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    print(f"\nEpoch {epoch+1}")

    for i, grad in enumerate(gradients):
        print(f"Gradient {i+1}: Mean = {tf.reduce_mean(tf.abs(grad)).numpy():.6f}")
# Out:
# Epoch 1
# Gradient 1: Mean = 0.026427
# Gradient 2: Mean = 0.024853
# Gradient 3: Mean = 0.052359
# Gradient 4: Mean = 0.040233
# Gradient 5: Mean = 0.050976
#
# Epoch 2
# Gradient 1: Mean = 0.025198
# Gradient 2: Mean = 0.024112
# Gradient 3: Mean = 0.049371
# Gradient 4: Mean = 0.039827
# Gradient 5: Mean = 0.046293
#
# Epoch 3
# Gradient 1: Mean = 0.024274
# Gradient 2: Mean = 0.023444
# Gradient 3: Mean = 0.046414
# Gradient 4: Mean = 0.039404
# Gradient 5: Mean = 0.041667
#
# Epoch 4
# Gradient 1: Mean = 0.023510
# Gradient 2: Mean = 0.022788
# Gradient 3: Mean = 0.043497
# Gradient 4: Mean = 0.038975
# Gradient 5: Mean = 0.037144
#
# Epoch 5
# Gradient 1: Mean = 0.022754
# Gradient 2: Mean = 0.022143
# Gradient 3: Mean = 0.040612
# Gradient 4: Mean = 0.038546
# Gradient 5: Mean = 0.032733

# %%
"""  
                 Previous Hidden State (hₜ₋₁)
                           │
                           ▼
                   +-----------------+
Input (xₜ) ------->|  Forget Gate    |-----> Keeps or removes old memory
                   +-----------------+
                           │
                           ▼
                 Previous Cell State (Cₜ₋₁)
                           │
                           ▼
                   +-----------------+
                   |   Input Gate    |-----> Decides what new information to store
                   +-----------------+
                           │
                           ▼
                    Updated Cell State (Cₜ)
                           │
                           ▼
                   +-----------------+
                   |  Output Gate    |-----> Decides what information becomes the hidden state
                   +-----------------+
                           │
                           ▼
                  Hidden State (hₜ)

"""
# Out:
# '  \n                 Previous Hidden State (hₜ₋₁)\n                           │\n                           ▼\n                   +-----------------+\nInput (xₜ) ------->|  Forget Gate    |-----> Keeps or removes old memory\n                   +-----------------+\n                           │\n                           ▼\n                 Previous Cell State (Cₜ₋₁)\n                           │\n                           ▼\n                   +-----------------+\n                   |   Input Gate    |-----> Decides what new information to store\n                   +-----------------+\n                           │\n                           ▼\n                    Updated Cell State (Cₜ)\n                           │\n                           ▼\n                   +-----------------+\n                   |  Output Gate    |-----> Decides what information becomes the hidden state\n                   +-----------------+\n                           │\n                           ▼\n  
# ...

# %%
print("User Food Order Sequence:")
orders = ["pizza", "burger", "pasta", "pizza"]

print(orders)

print("\nTime Step 1 (Input = Pizza)")
print("Forget Gate = 0")
print("Input Gate  = 1")
print("Output Gate = 1")
print("Memory: Store 'Pizza'")

print("\nTime Step 2 (Input = Burger)")
print("Forget Gate = 1")
print("Input Gate  = 1")
print("Output Gate = 1")
print("Memory: Keep 'Pizza' and Add 'Burger'")
# Out:
# User Food Order Sequence:
# ['pizza', 'burger', 'pasta', 'pizza']
#
# Time Step 1 (Input = Pizza)
# Forget Gate = 0
# Input Gate  = 1
# Output Gate = 1
# Memory: Store 'Pizza'
#
# Time Step 2 (Input = Burger)
# Forget Gate = 1
# Input Gate  = 1
# Output Gate = 1
# Memory: Keep 'Pizza' and Add 'Burger'

# %%
print("Unrolling an LSTM Through Time\n")

print("An LSTM is unrolled through time by applying the same LSTM cell")
print("to each element of a sequence while passing the hidden state")
print("and cell state from one time step to the next.")

print("\nExample:")
print("In a music playlist app, the LSTM processes each song played")
print("by the user one after another. Information about previously")
print("played songs is carried forward, helping the model predict")
print("the next song the user is most likely to listen to.")
# Out:
# Unrolling an LSTM Through Time
#
# An LSTM is unrolled through time by applying the same LSTM cell
# to each element of a sequence while passing the hidden state
# and cell state from one time step to the next.
#
# Example:
# In a music playlist app, the LSTM processes each song played
# by the user one after another. Information about previously
# played songs is carried forward, helping the model predict
# the next song the user is most likely to listen to.
