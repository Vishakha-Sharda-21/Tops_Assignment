# %%
# Task 1

def calculate_mse(predictions, targets):

    n = len(predictions)

    squared_error_sum = 0

    for pred, target in zip(predictions, targets):
        squared_error_sum += (pred - target) ** 2

    mse = squared_error_sum / n

    return mse


# Example

predictions = [4.5, 3.2, 4.8, 2.1]
targets = [5, 3, 5, 2]

result = calculate_mse(predictions, targets)

print("Mean Squared Error (MSE):", result)
# Out:
# Mean Squared Error (MSE): 0.08500000000000005

# %%
# Task 2

actual_ratings = [4, 3, 5, 2, 1]

predicted_ratings = [5, 2, 4, 2, 1]

absolute_error_sum = 0

for actual, predicted in zip(actual_ratings, predicted_ratings):

    absolute_error_sum += abs(actual - predicted)

mae = absolute_error_sum / len(actual_ratings)

print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Absolute Error (MAE): 0.6

# %%
# Task 3

import math

def binary_cross_entropy(y_true, y_pred):

    n = len(y_true)

    loss = 0

    for yt, yp in zip(y_true, y_pred):

        loss += yt * math.log(yp) + (1 - yt) * math.log(1 - yp)

    return -loss / n


# Test Data

y_true = [1, 0, 1]

y_pred = [0.9, 0.2, 0.7]

result = binary_cross_entropy(y_true, y_pred)

print("Binary Cross Entropy Loss:", round(result, 4))
# Out:
# Binary Cross Entropy Loss: 0.2284

# %%
# Task 4

import math

y_true = [0, 0, 1]

y_pred = [0.2, 0.3, 0.5]

loss = 0

for actual, predicted in zip(y_true, y_pred):

    loss += actual * math.log(predicted)

loss = -loss

print("Categorical Cross Entropy Loss:", round(loss, 4))
# Out:
# Categorical Cross Entropy Loss: 0.6931

# %%
# Task 5

print("Application: Spotify")
print()

print("Scenario:")
print("Predict whether a user will like a recommended song.")
print()

print("Possible Outputs:")
print("1 = User likes the song")
print("0 = User skips the song")
print()

print("Chosen Loss Function:")
print("Binary Cross Entropy")
print()

print("Reason:")
print("The problem has only two outcomes:")
print("Like or Dislike.")
print("Binary Cross Entropy measures how close")
print("predicted probabilities are to actual labels.")
# Out:
# Application: Spotify
#
# Scenario:
# Predict whether a user will like a recommended song.
#
# Possible Outputs:
# 1 = User likes the song
# 0 = User skips the song
#
# Chosen Loss Function:
# Binary Cross Entropy
#
# Reason:
# The problem has only two outcomes:
# Like or Dislike.
# Binary Cross Entropy measures how close
# predicted probabilities are to actual labels.
